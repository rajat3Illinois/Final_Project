# %%
import pandas as pd
import json as json

# %%
test_data = pd.read_csv('Heart_Attack_detail.csv')
test_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3ca8ca838fa6> in <module>
# ----> 1 test_data = pd.read_csv('Heart_Attack_detail.csv')
#       2 test_data
#
# ...

# %%
test_data['ObjectId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 247    248
# 248    249
# 249    250
# 250    251
# 251    252
# Name: ObjectId, Length: 252, dtype: int64

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
earthquake = gpd.read_file('Heart_Attack_detail.geojson')
earthquake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b5f98f10710b> in <module>
# ----> 1 earthquake = gpd.read_file('Heart_Attack_detail.geojson')
#       2 earthquake
#
# NameError: name 'gpd' is not defined

# %%
skyscrapper = pd.read_csv('skyscrapers.csv')
skyscrapper
# Out:
#          id   material                      name  location_city  \
# 0        12      steel              The Illinois        Chicago
# 1        62  composite             Chicago Spire        Chicago
# 2        68  composite  Miglin-Beitler Skyneedle        Chicago
# 3        98  composite    One World Trade Center  New York City
# 4     14269   concrete        Central Park Tower  New York City
# ...     ...        ...                       ...            ...
# 2426  18633   concrete           Hallets Point 2  New York City
# 2427  18635   concrete           Hallets Point 3  New York City
# 2428  18636   concrete           Hallets Point 4  New York City
# 2429  18637   concrete           Hallets Point 5  New York City
# 2430  18638   concrete           Hallets Point 6  New York City
#
#       location_city_id location.country  location.country id  \
# 0                 1539               US                  163
# 1                 1539               US                  163
# ...

# %%
skyscrapper.describe()
# Out:
#                  id  location_city_id  location.country id  location_latitude  \
# count   2431.000000       2431.000000               2431.0        2431.000000
# mean   11482.640889       1613.459893                163.0          36.971992
# std     6694.202957         78.685554                  0.0           8.705251
# min       12.000000       1499.000000                163.0           0.000000
# 25%     4130.500000       1543.000000                163.0          34.051241
# 50%    11440.000000       1632.000000                163.0          40.724869
# 75%    16575.000000       1641.000000                163.0          41.876270
# max    24079.000000       2365.000000                163.0          61.215210
#
#        location_longitude  statistics.floors above  statistics.height  \
# count         2431.000000              2431.000000        2431.000000
# mean           -86.321463                35.624434         132.445401
# ...

# %%
skyscrapper.describe(include='all')
# Out:
#                   id  material                name  location_city  \
# count    2431.000000      2431                2431           2430
# unique           NaN         7                2356            160
# top              NaN  concrete  Wells Fargo Center  New York City
# freq             NaN      1366                   5            640
# mean    11482.640889       NaN                 NaN            NaN
# std      6694.202957       NaN                 NaN            NaN
# min        12.000000       NaN                 NaN            NaN
# 25%      4130.500000       NaN                 NaN            NaN
# 50%     11440.000000       NaN                 NaN            NaN
# 75%     16575.000000       NaN                 NaN            NaN
# max     24079.000000       NaN                 NaN            NaN
#
#         location_city_id location.country  location.country id  \
# count        2431.000000             2431               2431.0
# ...

# %%
a = skyscrapper['material'].unique()
print(sorted(a))
# Out:
# ['composite', 'concrete', 'concrete/steel', 'masonry', 'precast', 'steel', 'steel/concrete']
